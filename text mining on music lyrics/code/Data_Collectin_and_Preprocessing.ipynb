# %% [markdown]
# ## data collection and preprocessing

# %%
% matplotlib inline

# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# We do this to ignore several specific Pandas warnings
import warnings
import requests
import json
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Extract data from Million Song Subset which is 1.8G in size

# %%
import os, sys

dir_tree = 'C:\\Users\\10465\\Downloads\\millionsongsubset_full\\MillionSongSubset\\'

for dir_path, dir_names, file_names in os.walk(dir_tree):
    for file_name in file_names:
        try:
            os.rename(os.path.join(dir_path, file_name), os.path.join(dir_tree, file_name))
        except OSError:
            print ("Could not move %s " % os.join(dir_path, file_name))

# %% [markdown]
# ### Build an artist table with file,title, artist columns

# %%
def make_artist_table(base):

# Get file names

    files = [os.path.join(base,fn) for fn in os.listdir(base) if fn.endswith('.h5')]
    data = {'file':[], 'artist':[], 'title':[]}

    # Add artist and title data to dictionary
    for f in files:
        store = pd.HDFStore(f)
        title = store.root.metadata.songs.cols.title[0]
        artist = store.root.metadata.songs.cols.artist_name[0]
        data['file'].append(os.path.basename(f))
        data['title'].append(title.decode("utf-8"))
        data['artist'].append(artist.decode("utf-8"))
        store.close()
    
    # Convert dictionary to pandas DataFrame
    df = pd.DataFrame.from_dict(data, orient='columns')
    df = df[['file', 'artist', 'title']]
    return df

# %%
base = 'C:\\Users\\10465\\Downloads\\millionsongsubset_full\\MillionSongSubset\\'
df = make_artist_table(base)

df.tail()
# Out:
#                         file                    artist  \
# 9996   TRBIJMU12903CF892B.h5                 Moonspell
# 9997   TRBIJNF128F14815A7.h5            Danny Williams
# 9998   TRBIJNK128F93093EC.h5             Winston Reedy
# 9999   TRBIJRN128F425F3DD.h5  Myrick "Freeze" Guillory
# 10000  TRBIJYB128F14AE326.h5       Seventh Day Slumber
#
#                                   title
# 9996                     The Hanged Man
# 9997   The Wonderful World Of The Young
# 9998                    Sentimental Man
# 9999                  Zydeco In D-Minor
# 10000                    Shattered Life

# %% [markdown]
# ### Add the lyrics column

# %%
df['lyrics'] = pd.Series('', index=df.index)
df.tail()
# Out:
#                         file                    artist  \
# 9996   TRBIJMU12903CF892B.h5                 Moonspell
# 9997   TRBIJNF128F14815A7.h5            Danny Williams
# 9998   TRBIJNK128F93093EC.h5             Winston Reedy
# 9999   TRBIJRN128F425F3DD.h5  Myrick "Freeze" Guillory
# 10000  TRBIJYB128F14AE326.h5       Seventh Day Slumber
#
#                                   title lyrics
# 9996                     The Hanged Man
# 9997   The Wonderful World Of The Young
# 9998                    Sentimental Man
# 9999                  Zydeco In D-Minor
# 10000                    Shattered Life

# %% [markdown]
# ### download the PyLyrics package to download lyrics from the website

# %%
# !pip install PyLyrics
# Out:
# Collecting PyLyrics
#   Downloading PyLyrics-1.1.0.zip
# Requirement already satisfied (use --upgrade to upgrade): beautifulsoup4 in c:\users\10465\anaconda3\lib\site-packages (from PyLyrics)
# Requirement already satisfied (use --upgrade to upgrade): requests in c:\users\10465\anaconda3\lib\site-packages (from PyLyrics)
# Building wheels for collected packages: PyLyrics
#   Running setup.py bdist_wheel for PyLyrics: started
#   Running setup.py bdist_wheel for PyLyrics: finished with status 'done'
#   Stored in directory: C:\Users\10465\AppData\Local\pip\Cache\wheels\3e\1a\25\a4217f5896313da289878107ba12324d3044413d466b65f243
# Successfully built PyLyrics
# Installing collected packages: PyLyrics
# Successfully installed PyLyrics-1.1.0
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from PyLyrics import *

# %%
# from PyLyrics import *
## test this function
print(PyLyrics.getLyrics('Taylor Swift','Blank Space')) #Print the lyrics directly
# Out:
# Nice to meet you, where you been?
# I could show you incredible things
# Magic, madness, heaven, sins
# Saw you there and I thought
#
# "Oh my God, look at that face!"
# You look like my next mistake
# Love's a game, wanna play?
#
# New money, suit and tie
# I can read you like a magazine
# Ain't it funny, rumors fly
# And I know you heard about me
#
# So hey, let's be friends
# I'm dying to see how this one ends
# Grab your passport and my hand
# I can make the bad guys good for a weekend
#
# So it's gonna be forever
# Or it's gonna go down in flames
# You can tell me when it's over (mmm)
# If the high was worth the pain
#
# Got a long list of ex-lovers
# They'll tell you I'm insane
# 'Cause you know I love the players
# And you love the game
#
# 'Cause we're young and we're reckless
# We'll take this way too far
# It'll leave you breathless (mmm)
# Or with a nasty scar
#
# Got a long list of ex-lovers
# They'll tell you I'm insane
# But I got a blank space, baby
# And I'll write your name
#
# Cherry lips, crystal skies
# I could show you incredible things
# Stolen kisses, pretty lies
# You're the king, baby, I'm your queen
#
# Find out what you want
# Be that girl for a month
# Wait, the worst is yet to come
# Oh no
#
# Screaming, crying, perfect storms
# I can make all the tables turn
# Rose garden filled with thorns
# Keep you second-guessing like
#
# "Oh my God, who is she?"
# I get drunk on jealousy
# But you'll come back each time you leave
# 'Cause darling, I'm a nightmare dressed like a daydream
#
# So it's gonna be forever
# Or it's gonna go down in flames
# You can tell me when it's over (mmm)
# If the high was worth the pain
#
# Got a long list of ex-lovers
# They'll tell you I'm insane
# 'Cause you know I love the players
# And you love the game
#
# 'Cause we're young and we're reckless (oh)
# We'll take this way too far
# It'll leave you breathless (mmm)
# Or with a nasty scar
#
# Got a long list of ex-lovers
# They'll tell you I'm insane
# But I got a blank space, baby
# And I'll write your name
#
# Boys only want love if it's torture
# Don't say I didn't, say I didn't warn ya
# Boys only want love if it's torture
# Don't say I didn't, say I didn't warn ya
#
# So it's gonna be forever
# Or it's gonna go down in flames
# You can tell me when it's over (over)
# If the high was worth the pain
#
# Got a long list of ex-lovers
# They'll tell you I'm insane
# 'Cause you know I love the players
# And you love the game
#
# 'Cause we're young and we're reckless
# We'll take this way too far (ooh)
# It'll leave you breathless (mmm)
# Or with a nasty scar
#
# Got a long list of ex-lovers
# They'll tell you I'm insane
# But I got a blank space, baby
# And I'll write your name

# %%
import pyprind

# %% [markdown]
# ### download lyrics with the arguments of artist and track name

# %%
pbar = pyprind.ProgBar(df.shape[0])
for row_id in df.index:
    try:
        lyr = PyLyrics.getLyrics(df.loc[row_id]['artist'],df.loc[row_id]['title'])    
        df.loc[row_id,'lyrics'] = lyr
        pbar.update()
    except: #ignore erro when API returns no lyrics 
        continue
# Out:
# 0% [############################# ] 100% | ETA: 00:00:09

# %%
print('downloaded Lyrics for %s songs' %sum(df.lyrics!=''))
df.head()
# Out:
# downloaded Lyrics for 1048 songs
#                          file        artist              title  \
# 0  subset_msd_summary_file.h5      Mastodon  Deep Sea Creature
# 1       TRAAAAW128F429D538.h5        Casual   I Didn't Mean To
# 2       TRAAABD128F429CF47.h5  The Box Tops          Soul Deep
# 4       TRAAAEF128F4273421.h5      Adam Ant    Something Girls
# 5       TRAAAFD128F92F423A.h5           Gob     Face the Ashes
#
#                                               lyrics
# 0  Knowing right, learning wrong\nWhat you're fee...
# 1  Verse One:\n\nAlright I might\nHave had a litt...
# 2  Darling, I don't know much\nBut I know I love ...
# 4  Adam Ant/Marco Pirroni\nEvery girl is a someth...
# 5  I've just erased it's been a while, I've got a...

# %%
df.to_csv('df_lyr_backup.csv')

# %% [markdown]
# ### drop rows that has no lyrics

# %%
df = df[df.lyrics!='']

# %% [markdown]
# ### remove songs that is not English song, cited from https://github.com/rasbt/musicmood

# %%
import nltk

def eng_ratio(text):
    ''' Returns the ratio of non-English to English words from a text '''

    english_vocab = set(w.lower() for w in nltk.corpus.words.words()) 
    text_vocab = set(w.lower() for w in text.split() if w.lower().isalpha()) 
    unusual = text_vocab.difference(english_vocab)
    diff = len(unusual)/len(text_vocab)
    return diff

# %%
before = df.shape[0]
for row_id in df.index:
    text = df.loc[row_id]['lyrics']
    diff = eng_ratio(text)
    if diff >= 0.5:
        df = df[df.index != row_id]
after = df.shape[0]
rem = before - after
print('%s have been removed.' %rem)
print('%s songs remain in the dataset.' %after)
# Out:
# 131 have been removed.
# 917 songs remain in the dataset.

# %% [markdown]
# ### Till now, we got the songs with lyrics, but we have to tag each song with mood. Here I download the tags from Last.fm and classified each some with happy mood or sad mood

# %%
def getSongTags(artist,track):
    url = "http://ws.audioscrobbler.com/2.0/?method=track.getTopTags&api_key=0f6916aff634cb3e768baa9d5ee89341&artist="+artist+"&track="+track+"&format=json"
#     print(url)
    results = requests.get(url).json()
#     print(results)
    tagList = []
    if 'toptags' in results:
        toptags = results['toptags']
        if 'tag' in toptags:
            taglistss = toptags['tag']           
            for tagItem in taglistss:
                tagList.append(tagItem['name']) 
    return tagList

# %%
df['tags'] = ''
pbar = pyprind.ProgBar(df.shape[0])
for row_id in df.index:
    tags = getSongTags(df.loc[row_id]['artist'],df.loc[row_id]['title'])    
    df.loc[row_id,'tags'] = tags
    pbar.update()
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:02:49

# %%
getSongTags("Mastodon","Deep Sea Creature")
# Out:
# ['Progressive metal',
#  'metal',
#  'Sludge',
#  'metalcore',
#  'rock',
#  'alternative metal',
#  'sludge metal',
#  'progressive stoner metal',
#  'heavy metal',
#  'hard rock',
#  'thrash metal',
#  'death metal',
#  'post-hardcore',
#  'wwe',
#  'Megadeth',
#  'Testament',
#  'exodus',
#  'Math core',
#  'attacker']

# %%
df['tags']
# df.head()
# Out:
# 0       [Progressive metal, metal, Sludge, metalcore, ...
# 1       [Bay Area, hieroglyiphics, Hip-Hop, classic, h...
# 2       [60s, soul, pop, rock, oldies, 1969, classic r...
# 4       [new wave, 80s, girls, freedom, strangeromanti...
# 5                                       [punk rock, punk]
# 9       [Progressive rock, classic rock, rock, hard ro...
# 15      [80s, all in a day, Lionel Richie, slowhand, v...
# 16      [classic rock, country, singer-songwriter, blu...
# 19      [hard rock, rock, chillout, Love, Favorite, ch...
# 24      [mathcore, hardcore, metal, experimental, meta...
# 25      [oldies, 60s girls, 60s, female vocalist, midb...
# 26          [metal, seen live, lie, the favouritest song]
# 29      [latin, latin jazz, jazz, Soundtrack, Latin-ja...
# 32                                [favourite, fave songs]
# 33                                                     []
# 34                                              [country]
# 42                                                     []
# 43                                                     []
# 45                                                     []
# 47      [blues rock, blues, rock, guitar, classic rock...
# 48                                 [blues, slide players]
# 49      [Lo-Fi, indie, indietronica, electronic, 8-bit...
# 52      [jazz, Bossa Nova, brazil, female vocalists, 2...
# 53                                                     []
# 54      [punk, hardcore punk, punk rock, la punk, Caco...
# 56      [christmas, xmas, Christmas Songs, Chris Rea, ...
# 59                [radio paradise, radioparadise, V-Show]
# 63      [grindcore, death metal, industrial metal, cyb...
# 64      [indie rock, indie, kings of leon, rock, Garag...
# 67      [punk, punk rock, nofx, punkrock, rock, altern...
#                               ...
# 3132    [pop, 80s, motown, soft rock, oldies, Guilty P...
# 3134                                                   []
# 3138                                     [funk, Funk Tag]
# 3139    [rock, Latin Rock, 70s, USA, funk, 8 of 10 sta...
# 3142                                                   []
# 3143    [punk, hardcore, street punk, Oi, mnmw, the br...
# 3147    [punk rock, rock, punk, emo, AFI, alternative,...
# 3154                                                   []
# 3156                                                   []
# 3159    [reggae, roots reggae, Bob Marley, strings org...
# 3160                                     [pop, christian]
# 3167    [camelot, Soundtrack, Broadway, welsh, if life...
# 3171    [80s, pop, dance, janet jackson, rnb, female v...
# 3173                                                   []
# 3174    [Chris Brown, so glad, pop rock, hip hop, r&b,...
# 3175    [alternative rock, punk, alternative, rock, ps...
# 3177                                                   []
# 3184                                                [rap]
# 3199    [Progressive rock, Psychedelic Rock, steven wi...
# 3202                                                   []
# 3204                                                   []
# 3205                        [metal, hardcore, Torquemada]
# 3206    [rock, Mellow, favourite, great song, Faves, m...
# 3207    [rock, classic rock, Eagles, soft rock, folk, ...
# 3210    [country, beautiful, great song, classic count...
# 3214    [rock, alternative rock, alternative, dave mat...
# 3218    [country, beautiful, 90s, great song, male voc...
# 3221    [hardcore, nyhc, punk, hardcore punk, new york...
# 3222    [hardcore, nyhc, yesss, hardcore old school, d...
# 3224    [Smooth Jazz, jazz, saxophone, kenny G, 80s, e...
# Name: tags, dtype: object

# %%
for row_id in df.index:     
    if len(df.loc[row_id,'tags'])==0:
        df = df.drop(row_id)

# %%
df['year'] = pd.Series('', index=df.index)

base = 'C:\\Users\\10465\\Downloads\\millionsongsubset_full\\MillionSongSubset\\'
files = [os.path.join(base,fn) for fn in os.listdir(base) if fn.endswith('.h5')]
for row_id in df.index:
    filename = df.loc[row_id]['file']
    filepath = os.path.join(base,filename)
    store = pd.HDFStore(filepath)
    year = store.root.musicbrainz.songs.cols.year[0]
    df.loc[row_id]['year'] = year

# %% [markdown]
# <img src="image.png">

# %%
df.shape[0]
# Out:
# 719

# %% [markdown]
# ## Happy or Sad
# ### Group id	Tags	num. of tags	num. of songs
# #### sad tags:
#
# G15	sad, sadness, unhappy, melancholic, melancholy, feeling sad, mood: sad - slightly, sad song	8	1,178
#
# G16	depressed, blue, dark, depressive, dreary, gloom, darkness, depress, depression, depressing, gloomy	11	471
#
# G28	anger, angry, choleric, fury, outraged, rage, angry music	7	254
#
# G17	grief, heartbreak, mournful, sorrow, sorry, doleful, heartache, heartbreaking, heartsick, lachrymose, mourning, plaintive, regret, sorrowful	14	183
#
# #### happy tags:
# G6	cheerful, cheer up, festive, jolly, jovial, merry, cheer, cheering, cheery, get happy, rejoice, songs that are cheerful, sunny	13	142
#
# G5	happy, happiness, happy songs, happy music, glad, mood: happy	6	749
#
# G2	upbeat, gleeful, high spirits, zest, enthusiastic, buoyancy, elation, mood: upbeat	8	543
#
# G1	excitement, exciting, exhilarating, thrill, ardor, stimulating, thrilling, titillating	8	30
# TOTAL		135	6,490
#
# ### This tag summary comes from the last.fm website which were group into different categories. Here, I choose group 15,16,28,17 as sad tag and group 5,6,2,1 as happy songs

# %%
happyTags = "cheerful, cheer up, festive, jolly, jovial, merry, cheer, cheering,\
cheery, get happy, rejoice, songs that are cheerful, sunny,happy, happiness, happy songs, happy music, glad, mood: happy,\
upbeat, gleeful, high spirits, zest, enthusiastic, buoyancy, elation, mood: upbeat,excitement, exciting, exhilarating, thrill,\
ardor, stimulating, thrilling, titillating"
happyTags = happyTags.replace(" ","").split(",")

sagTags = "sad, sadness, unhappy, melancholic, melancholy, feeling sad, mood: sad - slightly, sad song,\
depressed, blue, dark, depressive, dreary, gloom, darkness, depress, depression, depressing, gloomy,\
anger, angry, choleric, fury, outraged, rage, angry music,grief, heartbreak, mournful, sorrow, sorry, doleful, heartache, heartbreaking, heartsick, lachrymose, mourning,\
plaintive, regret, sorrowful"
sagTags = sagTags.replace(" ","").split(",")

# %%
happyTags
# Out:
# ['cheerful',
#  'cheerup',
#  'festive',
#  'jolly',
#  'jovial',
#  'merry',
#  'cheer',
#  'cheering',
#  'cheery',
#  'gethappy',
#  'rejoice',
#  'songsthatarecheerful',
#  'sunny',
#  'happy',
#  'happiness',
#  'happysongs',
#  'happymusic',
#  'glad',
#  'mood:happyupbeat',
#  'gleeful',
#  'highspirits',
#  'zest',
#  'enthusiastic',
#  'buoyancy',
#  'elation',
#  'mood:upbeat',
#  'excitement',
#  'exciting',
#  'exhilarating',
#  'thrill',
#  'ardor',
#  'stimulating',
#  'thrilling',
#  'titillating']

# %%
sagTags
# Out:
# ['sad',
#  'sadness',
#  'unhappy',
#  'melancholic',
#  'melancholy',
#  'feelingsad',
#  'mood:sad-slightly',
#  'sadsong',
#  'depressed',
#  'blue',
#  'dark',
#  'depressive',
#  'dreary',
#  'gloom',
#  'darkness',
#  'depress',
#  'depression',
#  'depressing',
#  'gloomy',
#  'anger',
#  'angry',
#  'choleric',
#  'fury',
#  'outraged',
#  'rage',
#  'angrymusic',
#  'grief',
#  'heartbreak',
#  'mournful',
#  'sorrow',
#  'sorry',
#  'doleful',
#  'heartache',
#  'heartbreaking',
#  'heartsick',
#  'lachrymose',
#  'mourning',
#  'plaintive',
#  'regret',
#  'sorrowful']

# %% [markdown]
# ### Based on the tag numbers from sad group or the happy group, we can assign a mood value 1(happy) or 0(sad) to the mood column

# %%
df['mood']=""
pbar = pyprind.ProgBar(df.shape[0])
for row_id in df.index:
    tags = df.loc[row_id,'tags']    
    sad_tags = np.intersect1d(tags,sagTags) 
    happy_tags = np.intersect1d(tags,happyTags)
    if len(sad_tags)>0 or len(happy_tags)>0:# having mood tag
        if len(sad_tags)>len(happy_tags):
            df.loc[row_id,'mood'] = 0
        else:
            df.loc[row_id,'mood'] = 1
    else:
        df = df.drop(row_id)# remove songs that does not have tag
    pbar.update()
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:01

# %%
df.shape[0]
# Out:
# 166

# %%
df['mood']
# Out:
# 24      1
# 29      1
# 49      1
# 56      1
# 75      1
# 76      0
# 79      0
# 87      0
# 88      0
# 116     0
# 139     0
# 167     1
# 180     0
# 189     1
# 198     0
# 205     1
# 214     0
# 226     1
# 232     1
# 236     1
# 242     0
# 259     0
# 281     1
# 321     1
# 352     1
# 372     1
# 410     0
# 411     0
# 443     1
# 449     0
#        ..
# 2627    0
# 2641    0
# 2655    0
# 2665    1
# 2672    0
# 2683    0
# 2730    0
# 2751    0
# 2804    1
# 2811    0
# 2837    1
# 2840    0
# 2858    1
# 2913    1
# 2920    1
# 2963    0
# 2971    0
# 2974    0
# 3050    0
# 3051    0
# 3067    1
# 3081    1
# 3085    1
# 3116    0
# 3128    0
# 3132    1
# 3147    0
# 3159    1
# 3171    1
# 3214    1
# Name: mood, dtype: object

# %%
df
# Out:
#                        file                             artist  \
# 24    TRAACER128F4290F96.h5          The Dillinger Escape Plan
# 29    TRAACNS128F14A2DF5.h5                        Willie Bobo
# 49    TRAADQX128F422B4CF.h5  Casiotone For The Painfully Alone
# 56    TRAAEEH128E0795DFE.h5                          Chris Rea
# 75    TRAAGCZ128F93210FD.h5                    Black Eyed Peas
# 76    TRAAGEC128E079252C.h5                    Nine Inch Nails
# 79    TRAAGJV128F1464090.h5                        Lesley Gore
# 87    TRAAGPH128F4273C8D.h5                      Savage Garden
# 88    TRAAGPJ128F428CD1B.h5            Queens Of The Stone Age
# 116   TRAAIHL128F92E6DDA.h5                        Boyz II Men
# 139   TRAAKAS128F4246013.h5                     Porcupine Tree
# 167   TRAAMJY128F92F5919.h5                            DJ Quik
# 180   TRAANLO128F422AE37.h5                    Cradle Of Filth
# 189   TRAAOJI128F1458DCD.h5                          Heaven 17
# 198   TRAAPFQ128F42684DB.h5                       Dimmu Borgir
# 205   TRAAPVV128F425D64C.h5                        Chris Brown
# 214   TRAAQIH128F428BDEA.h5                          Busdriver
# 226   TRAARHS128F931689D.h5                        The Killers
# 232   TRAASFP128F42980BD.h5                            Orbital
# 236   TRAASKQ128F4265E04.h5           Rage Against The Machine
# 242   TRAASZE128F93499AE.h5                              Agnes
# 259   TRAAUEO128E0780CB9.h5                            Placebo
# 281   TRAAVRJ128F92FF90A.h5                                !!!
# 321   TRABAFJ128F42AF24E.h5                    Backstreet Boys
# 352   TRABCUQ128E0783E2B.h5                       Gwen Stefani
# 372   TRABFKN12903CAF61B.h5                       All Time Low
# 410   TRABIPA128F1458F79.h5                   Public Image Ltd
# 411   TRABIQP128F427D0DD.h5                       Rise Against
# 443   TRABLMN128E0792687.h5                             Weezer
# 449   TRABLTP128F930DC6D.h5       Creedence Clearwater Revived
# ...                     ...                                ...
# 2627  TRAIUYZ128F425BD2F.h5                                Múm
# 2641  TRAIVZI128F42642DE.h5                    Backstreet Boys
# 2655  TRAIXFB128F423C5A8.h5                       Joy Division
# 2665  TRAIYDL128E0791583.h5                            Rihanna
# 2672  TRAIYZW128F9330F7D.h5                         Kanye West
# 2683  TRAIZWI128F4247EFD.h5                    Ashton Shepherd
# 2730  TRAJDHN128F92C2EEF.h5                    Michael Jackson
# 2751  TRAJFFF128F429874A.h5                          Lifehouse
# 2804  TRAJKMI128F4281107.h5                             Baby D
# 2811  TRAJKXS128F42340B5.h5                           The Cure
# 2837  TRAJNWY128E078907F.h5                           Cut Copy
# 2840  TRAJNYD128F9340A32.h5                           The Cars
# 2858  TRAJPIQ128F14819A8.h5                        The Rapture
# 2913  TRAJUPI128F9324529.h5                      Reel Big Fish
# 2920  TRAJVHI128F930EFAF.h5                            Beyoncé
# 2963  TRAJZWM128F4262BBD.h5                       Neil Diamond
# 2971  TRAKAGL128F148B3B7.h5                              Tesla
# 2974  TRAKARY128F427253E.h5                         The Ataris
# 3050  TRAKHXX128E07877EB.h5              Red Hot Chili Peppers
# 3051  TRAKHYP128E0792F07.h5                      Patty Griffin
# 3067  TRAKJNX128F92CF428.h5                             Fergie
# 3081  TRAKKTE128F934B0D9.h5                       THE CHIFFONS
# 3085  TRAKLHO128F42BA554.h5                 The Rolling Stones
# 3116  TRAKOPE128F421CE6A.h5                        Patsy Cline
# 3128  TRAKPHP128F42807B0.h5                            Incubus
# 3132  TRAKPND128F42389EA.h5                       Phil Collins
# 3147  TRAKQXJ128F147A028.h5                                AFI
# 3159  TRAKRXM128F4250E33.h5                         Bob Marley
# 3171  TRAKTWZ128EF35E206.h5                      Janet Jackson
# 3214  TRAKXMS12903CB36F2.h5                 DAVE MATTHEWS BAND
#
#                                           title  \
# 24              Setting Fire to Sleeping Giants
# 29                               Spanish Grease
# 49                          Nashville Parthenon
# 56                   Driving Home For Christmas
# 75                         Let's Get It Started
# 76                                        Metal
# 79                                It's My Party
# 87                        You Can Still Be Free
# 88                                 I Never Came
# 116                              On Bended Knee
# 139                                     Waiting
# 167                  Born and Raised In Compton
# 180                           Summer Dying Fast
# 189   (We Don't Need This) Fascist Groove Thang
# 198                        Master Of Disharmony
# 205                                     Forever
# 214              (Bloody Paw On The) Kill Floor
# 226                                    Spaceman
# 232                                  Illuminate
# 236                           Kick Out The Jams
# 242                              I Need You Now
# 259                         English Summer Rain
# 281                                  Myth Takes
# ...                                                 ...  ...
# 2627  [ambient, icelandic, electronic, experimental,...    0
# 2641  [pop, backstreet boys, boybands, 90s, Love, Ba...    0
# 2655  [post-punk, new wave, 80s, alternative, rock, ...    0
# 2665  [pop, rnb, Rihanna, soul, reggae, Hip-Hop, fem...    1
# 2672  [hip hop, pop, rnb, Hip-Hop, Kanye West, beaut...    0
# 2683      [country, heartache, ash, female, story song]    0
# 2730  [pop, 80s, michael jackson, rock, male vocalis...    0
# 2751  [rock, alternative, alternative rock, Lifehous...    0
# 2804  [dance, 90s, trance, House, jungle, Rave, fema...    1
# 2811  [new wave, 80s, post-punk, rock, The Cure, alt...    0
# 2837  [electronic, electro, indie, electronica, elec...    1
# 2840  [80s, new wave, pop, classic rock, rock, The C...    0
# 2858  [indie, dance-punk, electronic, dance, indie r...    1
# 2913           [alternative, dance, happy, ska, summer]    1
# 2920  [rnb, beyonce, pop, female vocalists, dance, H...    1
# 2963  [70s, oldies, Neil Diamond, pop, singer-songwr...    0
# 2971  [hard rock, Tesla, rock, classic rock, 80s, he...    0
# 2974  [emo, rock, pop punk, punk, punk rock, One Tre...    0
# 3050                                       [sexy, dark]    0
# 3051  [female vocalists, folk, acoustic, Alt-country...    0
# 3067  [pop, Hip-Hop, Fergie, female vocalists, rnb, ...    1
# 3081  [60s, oldies, Girl Groups, female vocalists, p...    1
# 3085  [rock, classic rock, 70s, the rolling stones, ...    1
# 3116  [country, cline, female vocalists, dark, depre...    0
# 3128  [rock, alternative rock, alternative, incubus,...    0
# 3132  [pop, 80s, motown, soft rock, oldies, Guilty P...    1
# 3147  [punk rock, rock, punk, emo, AFI, alternative,...    0
# 3159  [reggae, roots reggae, Bob Marley, strings org...    1
# 3171  [80s, pop, dance, janet jackson, rnb, female v...    1
# 3214  [rock, alternative rock, alternative, dave mat...    1
#
# [166 rows x 6 columns]

# %%
df['year'] = pd.Series('', index=df.index)

base = 'C:\\Users\\10465\\Downloads\\millionsongsubset_full\\MillionSongSubset\\'
files = [os.path.join(base,fn) for fn in os.listdir(base) if fn.endswith('.h5')]
for row_id in df.index:
    filename = df.loc[row_id]['file']
    filepath = os.path.join(base,filename)
    store = pd.HDFStore(filepath)
    year = store.root.musicbrainz.songs.cols.year[0]
    df.loc[row_id]['year'] = year

# %%
df
# Out:
#                        file                             artist  \
# 24    TRAACER128F4290F96.h5          The Dillinger Escape Plan
# 29    TRAACNS128F14A2DF5.h5                        Willie Bobo
# 49    TRAADQX128F422B4CF.h5  Casiotone For The Painfully Alone
# 56    TRAAEEH128E0795DFE.h5                          Chris Rea
# 75    TRAAGCZ128F93210FD.h5                    Black Eyed Peas
# 76    TRAAGEC128E079252C.h5                    Nine Inch Nails
# 79    TRAAGJV128F1464090.h5                        Lesley Gore
# 87    TRAAGPH128F4273C8D.h5                      Savage Garden
# 88    TRAAGPJ128F428CD1B.h5            Queens Of The Stone Age
# 116   TRAAIHL128F92E6DDA.h5                        Boyz II Men
# 139   TRAAKAS128F4246013.h5                     Porcupine Tree
# 167   TRAAMJY128F92F5919.h5                            DJ Quik
# 180   TRAANLO128F422AE37.h5                    Cradle Of Filth
# 189   TRAAOJI128F1458DCD.h5                          Heaven 17
# 198   TRAAPFQ128F42684DB.h5                       Dimmu Borgir
# 205   TRAAPVV128F425D64C.h5                        Chris Brown
# 214   TRAAQIH128F428BDEA.h5                          Busdriver
# 226   TRAARHS128F931689D.h5                        The Killers
# 232   TRAASFP128F42980BD.h5                            Orbital
# 236   TRAASKQ128F4265E04.h5           Rage Against The Machine
# 242   TRAASZE128F93499AE.h5                              Agnes
# 259   TRAAUEO128E0780CB9.h5                            Placebo
# 281   TRAAVRJ128F92FF90A.h5                                !!!
# 321   TRABAFJ128F42AF24E.h5                    Backstreet Boys
# 352   TRABCUQ128E0783E2B.h5                       Gwen Stefani
# 372   TRABFKN12903CAF61B.h5                       All Time Low
# 410   TRABIPA128F1458F79.h5                   Public Image Ltd
# 411   TRABIQP128F427D0DD.h5                       Rise Against
# 443   TRABLMN128E0792687.h5                             Weezer
# 449   TRABLTP128F930DC6D.h5       Creedence Clearwater Revived
# ...                     ...                                ...
# 2627  TRAIUYZ128F425BD2F.h5                                Múm
# 2641  TRAIVZI128F42642DE.h5                    Backstreet Boys
# 2655  TRAIXFB128F423C5A8.h5                       Joy Division
# 2665  TRAIYDL128E0791583.h5                            Rihanna
# 2672  TRAIYZW128F9330F7D.h5                         Kanye West
# 2683  TRAIZWI128F4247EFD.h5                    Ashton Shepherd
# 2730  TRAJDHN128F92C2EEF.h5                    Michael Jackson
# 2751  TRAJFFF128F429874A.h5                          Lifehouse
# 2804  TRAJKMI128F4281107.h5                             Baby D
# 2811  TRAJKXS128F42340B5.h5                           The Cure
# 2837  TRAJNWY128E078907F.h5                           Cut Copy
# 2840  TRAJNYD128F9340A32.h5                           The Cars
# 2858  TRAJPIQ128F14819A8.h5                        The Rapture
# 2913  TRAJUPI128F9324529.h5                      Reel Big Fish
# 2920  TRAJVHI128F930EFAF.h5                            Beyoncé
# 2963  TRAJZWM128F4262BBD.h5                       Neil Diamond
# 2971  TRAKAGL128F148B3B7.h5                              Tesla
# 2974  TRAKARY128F427253E.h5                         The Ataris
# 3050  TRAKHXX128E07877EB.h5              Red Hot Chili Peppers
# 3051  TRAKHYP128E0792F07.h5                      Patty Griffin
# 3067  TRAKJNX128F92CF428.h5                             Fergie
# 3081  TRAKKTE128F934B0D9.h5                       THE CHIFFONS
# 3085  TRAKLHO128F42BA554.h5                 The Rolling Stones
# 3116  TRAKOPE128F421CE6A.h5                        Patsy Cline
# 3128  TRAKPHP128F42807B0.h5                            Incubus
# 3132  TRAKPND128F42389EA.h5                       Phil Collins
# 3147  TRAKQXJ128F147A028.h5                                AFI
# 3159  TRAKRXM128F4250E33.h5                         Bob Marley
# 3171  TRAKTWZ128EF35E206.h5                      Janet Jackson
# 3214  TRAKXMS12903CB36F2.h5                 DAVE MATTHEWS BAND
#
#                                           title  \
# 24              Setting Fire to Sleeping Giants
# 29                               Spanish Grease
# 49                          Nashville Parthenon
# 56                   Driving Home For Christmas
# 236   [cover, rock, alternative rock, metal, Rage Ag...    1  2000
# 242   [pop, dance, female vocalists, swedish, Love, ...    0     0
# 259   [alternative rock, alternative, rock, Placebo,...    0  2003
# 281   [indie, dance, electronic, dance punk, indie r...    1  2007
# 321   [pop, 90s, backstreet boys, dance, boybands, B...    1  1999
# 352   [pop, gwen stefani, female vocalists, dance, j...    1  2004
# 372   [pop punk, All Time Low, punk rock, powerpop, ...    1  2007
# 410   [new wave, post-punk, wake up, classic rock, r...    0  1985
# 411   [punk rock, punk, melodic hardcore, Rise Again...    0  2001
# 443   [rock, alternative, indie rock, alternative ro...    1  2001
# 449   [classic rock, rock, 70s, Southern Rock, oldie...    0     0
# ...                                                 ...  ...   ...
# 2627  [ambient, icelandic, electronic, experimental,...    0  2004
# 2641  [pop, backstreet boys, boybands, 90s, Love, Ba...    0  2000
# 2655  [post-punk, new wave, 80s, alternative, rock, ...    0  1980
# 2665  [pop, rnb, Rihanna, soul, reggae, Hip-Hop, fem...    1  2005
# 2672  [hip hop, pop, rnb, Hip-Hop, Kanye West, beaut...    0  2008
# 2683      [country, heartache, ash, female, story song]    0  2008
# 2730  [pop, 80s, michael jackson, rock, male vocalis...    0  1987
# 2751  [rock, alternative, alternative rock, Lifehous...    0  2005
# 2804  [dance, 90s, trance, House, jungle, Rave, fema...    1     0
# 2811  [new wave, 80s, post-punk, rock, The Cure, alt...    0  2001
# 2837  [electronic, electro, indie, electronica, elec...    1  2004
# 2840  [80s, new wave, pop, classic rock, rock, The C...    0  1984
# 2858  [indie, dance-punk, electronic, dance, indie r...    1  2006
# 2913           [alternative, dance, happy, ska, summer]    1     0
# 2920  [rnb, beyonce, pop, female vocalists, dance, H...    1  2006
# 2963  [70s, oldies, Neil Diamond, pop, singer-songwr...    0  1972
# 2971  [hard rock, Tesla, rock, classic rock, 80s, he...    0  1986
# 2974  [emo, rock, pop punk, punk, punk rock, One Tre...    0  2003
# 3050                                       [sexy, dark]    0  1999
# 3051  [female vocalists, folk, acoustic, Alt-country...    0  1996
# 3067  [pop, Hip-Hop, Fergie, female vocalists, rnb, ...    1     0
# 3081  [60s, oldies, Girl Groups, female vocalists, p...    1  1963
# 3085  [rock, classic rock, 70s, the rolling stones, ...    1  1972
# 3116  [country, cline, female vocalists, dark, depre...    0  1995
# 3128  [rock, alternative rock, alternative, incubus,...    0  2001
# 3132  [pop, 80s, motown, soft rock, oldies, Guilty P...    1     0
# 3147  [punk rock, rock, punk, emo, AFI, alternative,...    0  2006
# 3159  [reggae, roots reggae, Bob Marley, strings org...    1  1996
# 3171  [80s, pop, dance, janet jackson, rnb, female v...    1  1986
# 3214  [rock, alternative rock, alternative, dave mat...    1  2001
#
# [166 rows x 7 columns]

# %%
# df.to_csv('lyrics_166.csv', index=False,encoding='utf-8')

# %%
df = df.drop("tags",axis=1)

# %%
len(df[df.mood==1])/166
# Out:
# 0.3795180722891566

# %%
# save songs with mood tag into csv file for training and keywords extraction
df.to_csv('lyrics_166.csv', index=False,encoding='utf-8')
